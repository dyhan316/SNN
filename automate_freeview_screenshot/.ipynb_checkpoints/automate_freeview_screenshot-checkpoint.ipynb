# %% [markdown]
# base_cmd = "freeview -v mri/brainmask.mgz -f surf/lh.white:edgecolor=yellow surf/lh.pial:edgecolor=red surf/rh.white:edgecolor=yellow surf/rh.pial:edgecolor=red -layout 1 -cc -nocursor"
#
#
#
#
#
# -viewport sagittal -slice 100 127 127 -ss  nomri_T1_sag_1.jpg -noquit
# -viewport sagittal -slice 130 127 127 -ss  nomri_T1_sag_2.jpg -noquit
#
# -viewport axial -slice 127 100 127 -ss  nomri_T1_ax_1.jpg -noquit
# -viewport axial -slice 127 130 127 -ss  nomri_T1_ax_2.jpg -noquit
#
# -viewport coronal -slice 127 127 100 -ss  nomri_T1_cor_1.jpg -noquit
# -viewport coronal -slice 127 127 130 -ss  nomri_T1_cor_2.jpg -noquit
#
# -quit

# %%
#def cmd_maker(view, slice_idx):
#    slice_str = " ".join([str(i) for i in slice_idx])
#    slice_pos = "_".join([f"{i:03d}" for i in slice_idx])
#    return f"-viewport {view} -slice {slice_str} -ss  ./img_save/T1_{view}_{slice_pos}.jpg -noquit"


def cmd_maker(view, idx):
    if view == 'sagittal' : 
        slice_idx = [idx, 127, 127]
    elif view == 'axial' : 
        slice_idx = [127, idx, 127]
    elif view == 'coronal':
        slice_idx = [127, 127, idx]
    else : 
        raise ValueError()
    slice_str = " ".join([str(i) for i in slice_idx])
    return f"-viewport {view} -slice {slice_str} -ss  ./img_save/T1_{view}_{idx:03d}.jpg -noquit"

# %%
cmd_maker('sagittal',12)
# Out:
# '-viewport sagittal -slice 12 127 127 -ss  ./img_save/T1_sagittal_012.jpg -noquit'

# %%
import os
os.makedirs("./img_save", exist_ok=True)
total_cmd_list = []

base_cmd = "freeview -v mri/brainmask.mgz -f surf/lh.white:edgecolor=yellow surf/lh.pial:edgecolor=red surf/rh.white:edgecolor=yellow surf/rh.pial:edgecolor=red -layout 1 -cc -nocursor"

total_cmd_list.append(base_cmd)


for i in range(50,200,1):
    total_cmd_list.append(cmd_maker('sagittal', i))
    
    total_cmd_list.append(cmd_maker('axial', i))
    
    total_cmd_list.append(cmd_maker('coronal', i))
total_cmd_list.append('-quit')

# %%
print('\n'.join(total_cmd_list))
# Out:
# freeview -v mri/brainmask.mgz -f surf/lh.white:edgecolor=yellow surf/lh.pial:edgecolor=red surf/rh.white:edgecolor=yellow surf/rh.pial:edgecolor=red -layout 1 -cc -nocursor
# -viewport sagittal -slice 0 127 127 -ss  ./img_save/T1_sagittal_000.jpg -noquit
# -viewport axial -slice 127 0 127 -ss  ./img_save/T1_axial_000.jpg -noquit
# -viewport coronal -slice 127 127 0 -ss  ./img_save/T1_coronal_000.jpg -noquit
# -viewport sagittal -slice 1 127 127 -ss  ./img_save/T1_sagittal_001.jpg -noquit
# -viewport axial -slice 127 1 127 -ss  ./img_save/T1_axial_001.jpg -noquit
# -viewport coronal -slice 127 127 1 -ss  ./img_save/T1_coronal_001.jpg -noquit
# -viewport sagittal -slice 2 127 127 -ss  ./img_save/T1_sagittal_002.jpg -noquit
# -viewport axial -slice 127 2 127 -ss  ./img_save/T1_axial_002.jpg -noquit
# -viewport coronal -slice 127 127 2 -ss  ./img_save/T1_coronal_002.jpg -noquit
# -viewport sagittal -slice 3 127 127 -ss  ./img_save/T1_sagittal_003.jpg -noquit
# -viewport axial -slice 127 3 127 -ss  ./img_save/T1_axial_003.jpg -noquit
# -viewport coronal -slice 127 127 3 -ss  ./img_save/T1_coronal_003.jpg -noquit
# -viewport sagittal -slice 4 127 127 -ss  ./img_save/T1_sagittal_004.jpg -noquit
# -viewport axial -slice 127 4 127 -ss  ./img_save/T1_axial_004.jpg -noquit
# -viewport coronal -slice 127 127 4 -ss  ./img_save/T1_coronal_004.jpg -noquit
# -viewport sagittal -slice 5 127 127 -ss  ./img_save/T1_sagittal_005.jpg -noquit
# -viewport axial -slice 127 5 127 -ss  ./img_save/T1_axial_005.jpg -noquit
# -viewport coronal -slice 127 127 5 -ss  ./img_save/T1_coronal_005.jpg -noquit
# -viewport sagittal -slice 6 127 127 -ss  ./img_save/T1_sagittal_006.jpg -noquit
# -viewport axial -slice 127 6 127 -ss  ./img_save/T1_axial_006.jpg -noquit
# -viewport coronal -slice 127 127 6 -ss  ./img_save/T1_coronal_006.jpg -noquit
# -viewport sagittal -slice 7 127 127 -ss  ./img_save/T1_sagittal_007.jpg -noquit
# -viewport axial -slice 127 7 127 -ss  ./img_save/T1_axial_007.jpg -noquit
# -viewport coronal -slice 127 127 7 -ss  ./img_save/T1_coronal_007.jpg -noquit
# -viewport sagittal -slice 8 127 127 -ss  ./img_save/T1_sagittal_008.jpg -noquit
# -viewport axial -slice 127 8 127 -ss  ./img_save/T1_axial_008.jpg -noquit
# -viewport coronal -slice 127 127 8 -ss  ./img_save/T1_coronal_008.jpg -noquit
# -viewport sagittal -slice 9 127 127 -ss  ./img_save/T1_sagittal_009.jpg -noquit
# -viewport axial -slice 127 9 127 -ss  ./img_save/T1_axial_009.jpg -noquit
# -viewport coronal -slice 127 127 9 -ss  ./img_save/T1_coronal_009.jpg -noquit
# -viewport sagittal -slice 10 127 127 -ss  ./img_save/T1_sagittal_010.jpg -noquit
# -viewport axial -slice 127 10 127 -ss  ./img_save/T1_axial_010.jpg -noquit
# -viewport coronal -slice 127 127 10 -ss  ./img_save/T1_coronal_010.jpg -noquit
# -viewport sagittal -slice 11 127 127 -ss  ./img_save/T1_sagittal_011.jpg -noquit
# -viewport axial -slice 127 11 127 -ss  ./img_save/T1_axial_011.jpg -noquit
# -viewport coronal -slice 127 127 11 -ss  ./img_save/T1_coronal_011.jpg -noquit
# -viewport sagittal -slice 12 127 127 -ss  ./img_save/T1_sagittal_012.jpg -noquit
# -viewport axial -slice 127 12 127 -ss  ./img_save/T1_axial_012.jpg -noquit
# -viewport coronal -slice 127 127 12 -ss  ./img_save/T1_coronal_012.jpg -noquit
# -viewport sagittal -slice 13 127 127 -ss  ./img_save/T1_sagittal_013.jpg -noquit
# -viewport axial -slice 127 13 127 -ss  ./img_save/T1_axial_013.jpg -noquit
# -viewport coronal -slice 127 127 13 -ss  ./img_save/T1_coronal_013.jpg -noquit
# -viewport sagittal -slice 14 127 127 -ss  ./img_save/T1_sagittal_014.jpg -noquit
# -viewport axial -slice 127 14 127 -ss  ./img_save/T1_axial_014.jpg -noquit
# -viewport coronal -slice 127 127 14 -ss  ./img_save/T1_coronal_014.jpg -noquit
# -viewport sagittal -slice 15 127 127 -ss  ./img_save/T1_sagittal_015.jpg -noquit
# -viewport axial -slice 127 15 127 -ss  ./img_save/T1_axial_015.jpg -noquit
# -viewport coronal -slice 127 127 15 -ss  ./img_save/T1_coronal_015.jpg -noquit
# -viewport sagittal -slice 16 127 127 -ss  ./img_save/T1_sagittal_016.jpg -noquit
# -viewport axial -slice 127 16 127 -ss  ./img_save/T1_axial_016.jpg -noquit
# -viewport coronal -slice 127 127 16 -ss  ./img_save/T1_coronal_016.jpg -noquit
# -viewport sagittal -slice 17 127 127 -ss  ./img_save/T1_sagittal_017.jpg -noquit
# -viewport axial -slice 127 17 127 -ss  ./img_save/T1_axial_017.jpg -noquit
# -viewport coronal -slice 127 127 17 -ss  ./img_save/T1_coronal_017.jpg -noquit
# -viewport sagittal -slice 18 127 127 -ss  ./img_save/T1_sagittal_018.jpg -noquit
# -viewport axial -slice 127 18 127 -ss  ./img_save/T1_axial_018.jpg -noquit
# -viewport coronal -slice 127 127 18 -ss  ./img_save/T1_coronal_018.jpg -noquit
# -viewport sagittal -slice 19 127 127 -ss  ./img_save/T1_sagittal_019.jpg -noquit
# -viewport axial -slice 127 19 127 -ss  ./img_save/T1_axial_019.jpg -noquit
# -viewport coronal -slice 127 127 19 -ss  ./img_save/T1_coronal_019.jpg -noquit
# -viewport sagittal -slice 20 127 127 -ss  ./img_save/T1_sagittal_020.jpg -noquit
# -viewport axial -slice 127 20 127 -ss  ./img_save/T1_axial_020.jpg -noquit
# -viewport coronal -slice 127 127 20 -ss  ./img_save/T1_coronal_020.jpg -noquit
# -viewport sagittal -slice 21 127 127 -ss  ./img_save/T1_sagittal_021.jpg -noquit
# -viewport axial -slice 127 21 127 -ss  ./img_save/T1_axial_021.jpg -noquit
# -viewport coronal -slice 127 127 21 -ss  ./img_save/T1_coronal_021.jpg -noquit
# -viewport sagittal -slice 22 127 127 -ss  ./img_save/T1_sagittal_022.jpg -noquit
# -viewport axial -slice 127 22 127 -ss  ./img_save/T1_axial_022.jpg -noquit
# -viewport coronal -slice 127 127 22 -ss  ./img_save/T1_coronal_022.jpg -noquit
# -viewport sagittal -slice 23 127 127 -ss  ./img_save/T1_sagittal_023.jpg -noquit
# -viewport axial -slice 127 23 127 -ss  ./img_save/T1_axial_023.jpg -noquit
# -viewport coronal -slice 127 127 23 -ss  ./img_save/T1_coronal_023.jpg -noquit
# -viewport sagittal -slice 24 127 127 -ss  ./img_save/T1_sagittal_024.jpg -noquit
# -viewport axial -slice 127 24 127 -ss  ./img_save/T1_axial_024.jpg -noquit
# -viewport coronal -slice 127 127 24 -ss  ./img_save/T1_coronal_024.jpg -noquit
# -viewport sagittal -slice 25 127 127 -ss  ./img_save/T1_sagittal_025.jpg -noquit
# -viewport axial -slice 127 25 127 -ss  ./img_save/T1_axial_025.jpg -noquit
# -viewport coronal -slice 127 127 25 -ss  ./img_save/T1_coronal_025.jpg -noquit
# -viewport sagittal -slice 26 127 127 -ss  ./img_save/T1_sagittal_026.jpg -noquit
# -viewport axial -slice 127 26 127 -ss  ./img_save/T1_axial_026.jpg -noquit
# -viewport coronal -slice 127 127 26 -ss  ./img_save/T1_coronal_026.jpg -noquit
# -viewport sagittal -slice 27 127 127 -ss  ./img_save/T1_sagittal_027.jpg -noquit
# -viewport axial -slice 127 27 127 -ss  ./img_save/T1_axial_027.jpg -noquit
# -viewport coronal -slice 127 127 27 -ss  ./img_save/T1_coronal_027.jpg -noquit
# -viewport sagittal -slice 28 127 127 -ss  ./img_save/T1_sagittal_028.jpg -noquit
# -viewport axial -slice 127 28 127 -ss  ./img_save/T1_axial_028.jpg -noquit
# -viewport coronal -slice 127 127 28 -ss  ./img_save/T1_coronal_028.jpg -noquit
# -viewport sagittal -slice 29 127 127 -ss  ./img_save/T1_sagittal_029.jpg -noquit
# -viewport axial -slice 127 29 127 -ss  ./img_save/T1_axial_029.jpg -noquit
# -viewport coronal -slice 127 127 29 -ss  ./img_save/T1_coronal_029.jpg -noquit
# -viewport sagittal -slice 30 127 127 -ss  ./img_save/T1_sagittal_030.jpg -noquit
# -viewport axial -slice 127 30 127 -ss  ./img_save/T1_axial_030.jpg -noquit
# -viewport coronal -slice 127 127 30 -ss  ./img_save/T1_coronal_030.jpg -noquit
# -viewport sagittal -slice 31 127 127 -ss  ./img_save/T1_sagittal_031.jpg -noquit
# -viewport axial -slice 127 31 127 -ss  ./img_save/T1_axial_031.jpg -noquit
# -viewport coronal -slice 127 127 31 -ss  ./img_save/T1_coronal_031.jpg -noquit
# -viewport sagittal -slice 32 127 127 -ss  ./img_save/T1_sagittal_032.jpg -noquit
# -viewport axial -slice 127 32 127 -ss  ./img_save/T1_axial_032.jpg -noquit
# -viewport coronal -slice 127 127 32 -ss  ./img_save/T1_coronal_032.jpg -noquit
# -viewport sagittal -slice 33 127 127 -ss  ./img_save/T1_sagittal_033.jpg -noquit
# -viewport axial -slice 127 33 127 -ss  ./img_save/T1_axial_033.jpg -noquit
# -viewport coronal -slice 127 127 33 -ss  ./img_save/T1_coronal_033.jpg -noquit
# -viewport sagittal -slice 34 127 127 -ss  ./img_save/T1_sagittal_034.jpg -noquit
# -viewport axial -slice 127 34 127 -ss  ./img_save/T1_axial_034.jpg -noquit
# -viewport coronal -slice 127 127 34 -ss  ./img_save/T1_coronal_034.jpg -noquit
# -viewport sagittal -slice 35 127 127 -ss  ./img_save/T1_sagittal_035.jpg -noquit
# -viewport axial -slice 127 35 127 -ss  ./img_save/T1_axial_035.jpg -noquit
# -viewport coronal -slice 127 127 35 -ss  ./img_save/T1_coronal_035.jpg -noquit
# -viewport sagittal -slice 36 127 127 -ss  ./img_save/T1_sagittal_036.jpg -noquit
# -viewport axial -slice 127 36 127 -ss  ./img_save/T1_axial_036.jpg -noquit
# -viewport coronal -slice 127 127 36 -ss  ./img_save/T1_coronal_036.jpg -noquit
# -viewport sagittal -slice 37 127 127 -ss  ./img_save/T1_sagittal_037.jpg -noquit
# -viewport axial -slice 127 37 127 -ss  ./img_save/T1_axial_037.jpg -noquit
# -viewport coronal -slice 127 127 37 -ss  ./img_save/T1_coronal_037.jpg -noquit
# -viewport sagittal -slice 38 127 127 -ss  ./img_save/T1_sagittal_038.jpg -noquit
# -viewport axial -slice 127 38 127 -ss  ./img_save/T1_axial_038.jpg -noquit
# -viewport coronal -slice 127 127 38 -ss  ./img_save/T1_coronal_038.jpg -noquit
# -viewport sagittal -slice 39 127 127 -ss  ./img_save/T1_sagittal_039.jpg -noquit
# -viewport axial -slice 127 39 127 -ss  ./img_save/T1_axial_039.jpg -noquit
# -viewport coronal -slice 127 127 39 -ss  ./img_save/T1_coronal_039.jpg -noquit
# -viewport sagittal -slice 40 127 127 -ss  ./img_save/T1_sagittal_040.jpg -noquit
# -viewport axial -slice 127 40 127 -ss  ./img_save/T1_axial_040.jpg -noquit
# -viewport coronal -slice 127 127 40 -ss  ./img_save/T1_coronal_040.jpg -noquit
# -viewport sagittal -slice 41 127 127 -ss  ./img_save/T1_sagittal_041.jpg -noquit
# -viewport axial -slice 127 41 127 -ss  ./img_save/T1_axial_041.jpg -noquit
# -viewport coronal -slice 127 127 41 -ss  ./img_save/T1_coronal_041.jpg -noquit
# -viewport sagittal -slice 42 127 127 -ss  ./img_save/T1_sagittal_042.jpg -noquit
# -viewport axial -slice 127 42 127 -ss  ./img_save/T1_axial_042.jpg -noquit
# -viewport coronal -slice 127 127 42 -ss  ./img_save/T1_coronal_042.jpg -noquit
# -viewport sagittal -slice 43 127 127 -ss  ./img_save/T1_sagittal_043.jpg -noquit
# -viewport axial -slice 127 43 127 -ss  ./img_save/T1_axial_043.jpg -noquit
# -viewport coronal -slice 127 127 43 -ss  ./img_save/T1_coronal_043.jpg -noquit
# -viewport sagittal -slice 44 127 127 -ss  ./img_save/T1_sagittal_044.jpg -noquit
# -viewport axial -slice 127 44 127 -ss  ./img_save/T1_axial_044.jpg -noquit
# -viewport coronal -slice 127 127 44 -ss  ./img_save/T1_coronal_044.jpg -noquit
# -viewport sagittal -slice 45 127 127 -ss  ./img_save/T1_sagittal_045.jpg -noquit
# -viewport axial -slice 127 45 127 -ss  ./img_save/T1_axial_045.jpg -noquit
# -viewport coronal -slice 127 127 45 -ss  ./img_save/T1_coronal_045.jpg -noquit
# -viewport sagittal -slice 46 127 127 -ss  ./img_save/T1_sagittal_046.jpg -noquit
# -viewport axial -slice 127 46 127 -ss  ./img_save/T1_axial_046.jpg -noquit
# -viewport coronal -slice 127 127 46 -ss  ./img_save/T1_coronal_046.jpg -noquit
# -viewport sagittal -slice 47 127 127 -ss  ./img_save/T1_sagittal_047.jpg -noquit
# -viewport axial -slice 127 47 127 -ss  ./img_save/T1_axial_047.jpg -noquit
# -viewport coronal -slice 127 127 47 -ss  ./img_save/T1_coronal_047.jpg -noquit
# -viewport sagittal -slice 48 127 127 -ss  ./img_save/T1_sagittal_048.jpg -noquit
# -viewport axial -slice 127 48 127 -ss  ./img_save/T1_axial_048.jpg -noquit
# -viewport coronal -slice 127 127 48 -ss  ./img_save/T1_coronal_048.jpg -noquit
# -viewport sagittal -slice 49 127 127 -ss  ./img_save/T1_sagittal_049.jpg -noquit
# -viewport axial -slice 127 49 127 -ss  ./img_save/T1_axial_049.jpg -noquit
# -viewport coronal -slice 127 127 49 -ss  ./img_save/T1_coronal_049.jpg -noquit
# -viewport sagittal -slice 50 127 127 -ss  ./img_save/T1_sagittal_050.jpg -noquit
# -viewport axial -slice 127 50 127 -ss  ./img_save/T1_axial_050.jpg -noquit
# -viewport coronal -slice 127 127 50 -ss  ./img_save/T1_coronal_050.jpg -noquit
# -viewport sagittal -slice 51 127 127 -ss  ./img_save/T1_sagittal_051.jpg -noquit
# -viewport axial -slice 127 51 127 -ss  ./img_save/T1_axial_051.jpg -noquit
# -viewport coronal -slice 127 127 51 -ss  ./img_save/T1_coronal_051.jpg -noquit
# -viewport sagittal -slice 52 127 127 -ss  ./img_save/T1_sagittal_052.jpg -noquit
# -viewport axial -slice 127 52 127 -ss  ./img_save/T1_axial_052.jpg -noquit
# -viewport coronal -slice 127 127 52 -ss  ./img_save/T1_coronal_052.jpg -noquit
# -viewport sagittal -slice 53 127 127 -ss  ./img_save/T1_sagittal_053.jpg -noquit
# -viewport axial -slice 127 53 127 -ss  ./img_save/T1_axial_053.jpg -noquit
# -viewport coronal -slice 127 127 53 -ss  ./img_save/T1_coronal_053.jpg -noquit
# -viewport sagittal -slice 54 127 127 -ss  ./img_save/T1_sagittal_054.jpg -noquit
# -viewport axial -slice 127 54 127 -ss  ./img_save/T1_axial_054.jpg -noquit
# -viewport coronal -slice 127 127 54 -ss  ./img_save/T1_coronal_054.jpg -noquit
# -viewport sagittal -slice 55 127 127 -ss  ./img_save/T1_sagittal_055.jpg -noquit
# -viewport axial -slice 127 55 127 -ss  ./img_save/T1_axial_055.jpg -noquit
# -viewport coronal -slice 127 127 55 -ss  ./img_save/T1_coronal_055.jpg -noquit
# -viewport sagittal -slice 56 127 127 -ss  ./img_save/T1_sagittal_056.jpg -noquit
# -viewport axial -slice 127 56 127 -ss  ./img_save/T1_axial_056.jpg -noquit
# -viewport coronal -slice 127 127 56 -ss  ./img_save/T1_coronal_056.jpg -noquit
# -viewport sagittal -slice 57 127 127 -ss  ./img_save/T1_sagittal_057.jpg -noquit
# -viewport axial -slice 127 57 127 -ss  ./img_save/T1_axial_057.jpg -noquit
# -viewport coronal -slice 127 127 57 -ss  ./img_save/T1_coronal_057.jpg -noquit
# -viewport sagittal -slice 58 127 127 -ss  ./img_save/T1_sagittal_058.jpg -noquit
# -viewport axial -slice 127 58 127 -ss  ./img_save/T1_axial_058.jpg -noquit
# -viewport coronal -slice 127 127 58 -ss  ./img_save/T1_coronal_058.jpg -noquit
# -viewport sagittal -slice 59 127 127 -ss  ./img_save/T1_sagittal_059.jpg -noquit
# -viewport axial -slice 127 59 127 -ss  ./img_save/T1_axial_059.jpg -noquit
# -viewport coronal -slice 127 127 59 -ss  ./img_save/T1_coronal_059.jpg -noquit
# -viewport sagittal -slice 60 127 127 -ss  ./img_save/T1_sagittal_060.jpg -noquit
# -viewport axial -slice 127 60 127 -ss  ./img_save/T1_axial_060.jpg -noquit
# -viewport coronal -slice 127 127 60 -ss  ./img_save/T1_coronal_060.jpg -noquit
# -viewport sagittal -slice 61 127 127 -ss  ./img_save/T1_sagittal_061.jpg -noquit
# -viewport axial -slice 127 61 127 -ss  ./img_save/T1_axial_061.jpg -noquit
# -viewport coronal -slice 127 127 61 -ss  ./img_save/T1_coronal_061.jpg -noquit
# -viewport sagittal -slice 62 127 127 -ss  ./img_save/T1_sagittal_062.jpg -noquit
# -viewport axial -slice 127 62 127 -ss  ./img_save/T1_axial_062.jpg -noquit
# -viewport coronal -slice 127 127 62 -ss  ./img_save/T1_coronal_062.jpg -noquit
# -viewport sagittal -slice 63 127 127 -ss  ./img_save/T1_sagittal_063.jpg -noquit
# -viewport axial -slice 127 63 127 -ss  ./img_save/T1_axial_063.jpg -noquit
# -viewport coronal -slice 127 127 63 -ss  ./img_save/T1_coronal_063.jpg -noquit
# -viewport sagittal -slice 64 127 127 -ss  ./img_save/T1_sagittal_064.jpg -noquit
# -viewport axial -slice 127 64 127 -ss  ./img_save/T1_axial_064.jpg -noquit
# -viewport coronal -slice 127 127 64 -ss  ./img_save/T1_coronal_064.jpg -noquit
# -viewport sagittal -slice 65 127 127 -ss  ./img_save/T1_sagittal_065.jpg -noquit
# -viewport axial -slice 127 65 127 -ss  ./img_save/T1_axial_065.jpg -noquit
# -viewport coronal -slice 127 127 65 -ss  ./img_save/T1_coronal_065.jpg -noquit
# -viewport sagittal -slice 66 127 127 -ss  ./img_save/T1_sagittal_066.jpg -noquit
# -viewport axial -slice 127 66 127 -ss  ./img_save/T1_axial_066.jpg -noquit
# -viewport coronal -slice 127 127 66 -ss  ./img_save/T1_coronal_066.jpg -noquit
# -viewport sagittal -slice 67 127 127 -ss  ./img_save/T1_sagittal_067.jpg -noquit
# -viewport axial -slice 127 67 127 -ss  ./img_save/T1_axial_067.jpg -noquit
# -viewport coronal -slice 127 127 67 -ss  ./img_save/T1_coronal_067.jpg -noquit
# -viewport sagittal -slice 68 127 127 -ss  ./img_save/T1_sagittal_068.jpg -noquit
# -viewport axial -slice 127 68 127 -ss  ./img_save/T1_axial_068.jpg -noquit
# -viewport coronal -slice 127 127 68 -ss  ./img_save/T1_coronal_068.jpg -noquit
# -viewport sagittal -slice 69 127 127 -ss  ./img_save/T1_sagittal_069.jpg -noquit
# -viewport axial -slice 127 69 127 -ss  ./img_save/T1_axial_069.jpg -noquit
# -viewport coronal -slice 127 127 69 -ss  ./img_save/T1_coronal_069.jpg -noquit
# -viewport sagittal -slice 70 127 127 -ss  ./img_save/T1_sagittal_070.jpg -noquit
# -viewport axial -slice 127 70 127 -ss  ./img_save/T1_axial_070.jpg -noquit
# -viewport coronal -slice 127 127 70 -ss  ./img_save/T1_coronal_070.jpg -noquit
# -viewport sagittal -slice 71 127 127 -ss  ./img_save/T1_sagittal_071.jpg -noquit
# -viewport axial -slice 127 71 127 -ss  ./img_save/T1_axial_071.jpg -noquit
# -viewport coronal -slice 127 127 71 -ss  ./img_save/T1_coronal_071.jpg -noquit
# -viewport sagittal -slice 72 127 127 -ss  ./img_save/T1_sagittal_072.jpg -noquit
# -viewport axial -slice 127 72 127 -ss  ./img_save/T1_axial_072.jpg -noquit
# -viewport coronal -slice 127 127 72 -ss  ./img_save/T1_coronal_072.jpg -noquit
# -viewport sagittal -slice 73 127 127 -ss  ./img_save/T1_sagittal_073.jpg -noquit
# -viewport axial -slice 127 73 127 -ss  ./img_save/T1_axial_073.jpg -noquit
# -viewport coronal -slice 127 127 73 -ss  ./img_save/T1_coronal_073.jpg -noquit
# -viewport sagittal -slice 74 127 127 -ss  ./img_save/T1_sagittal_074.jpg -noquit
# -viewport axial -slice 127 74 127 -ss  ./img_save/T1_axial_074.jpg -noquit
# -viewport coronal -slice 127 127 74 -ss  ./img_save/T1_coronal_074.jpg -noquit
# -viewport sagittal -slice 75 127 127 -ss  ./img_save/T1_sagittal_075.jpg -noquit
# -viewport axial -slice 127 75 127 -ss  ./img_save/T1_axial_075.jpg -noquit
# -viewport coronal -slice 127 127 75 -ss  ./img_save/T1_coronal_075.jpg -noquit
# -viewport sagittal -slice 76 127 127 -ss  ./img_save/T1_sagittal_076.jpg -noquit
# -viewport axial -slice 127 76 127 -ss  ./img_save/T1_axial_076.jpg -noquit
# -viewport coronal -slice 127 127 76 -ss  ./img_save/T1_coronal_076.jpg -noquit
# -viewport sagittal -slice 77 127 127 -ss  ./img_save/T1_sagittal_077.jpg -noquit
# -viewport axial -slice 127 77 127 -ss  ./img_save/T1_axial_077.jpg -noquit
# -viewport coronal -slice 127 127 77 -ss  ./img_save/T1_coronal_077.jpg -noquit
# -viewport sagittal -slice 78 127 127 -ss  ./img_save/T1_sagittal_078.jpg -noquit
# -viewport axial -slice 127 78 127 -ss  ./img_save/T1_axial_078.jpg -noquit
# -viewport coronal -slice 127 127 78 -ss  ./img_save/T1_coronal_078.jpg -noquit
# -viewport sagittal -slice 79 127 127 -ss  ./img_save/T1_sagittal_079.jpg -noquit
# -viewport axial -slice 127 79 127 -ss  ./img_save/T1_axial_079.jpg -noquit
# -viewport coronal -slice 127 127 79 -ss  ./img_save/T1_coronal_079.jpg -noquit
# -viewport sagittal -slice 80 127 127 -ss  ./img_save/T1_sagittal_080.jpg -noquit
# -viewport axial -slice 127 80 127 -ss  ./img_save/T1_axial_080.jpg -noquit
# -viewport coronal -slice 127 127 80 -ss  ./img_save/T1_coronal_080.jpg -noquit
# -viewport sagittal -slice 81 127 127 -ss  ./img_save/T1_sagittal_081.jpg -noquit
# -viewport axial -slice 127 81 127 -ss  ./img_save/T1_axial_081.jpg -noquit
# -viewport coronal -slice 127 127 81 -ss  ./img_save/T1_coronal_081.jpg -noquit
# -viewport sagittal -slice 82 127 127 -ss  ./img_save/T1_sagittal_082.jpg -noquit
# -viewport axial -slice 127 82 127 -ss  ./img_save/T1_axial_082.jpg -noquit
# -viewport coronal -slice 127 127 82 -ss  ./img_save/T1_coronal_082.jpg -noquit
# -viewport sagittal -slice 83 127 127 -ss  ./img_save/T1_sagittal_083.jpg -noquit
# -viewport axial -slice 127 83 127 -ss  ./img_save/T1_axial_083.jpg -noquit
# -viewport coronal -slice 127 127 83 -ss  ./img_save/T1_coronal_083.jpg -noquit
# -viewport sagittal -slice 84 127 127 -ss  ./img_save/T1_sagittal_084.jpg -noquit
# -viewport axial -slice 127 84 127 -ss  ./img_save/T1_axial_084.jpg -noquit
# -viewport coronal -slice 127 127 84 -ss  ./img_save/T1_coronal_084.jpg -noquit
# -viewport sagittal -slice 85 127 127 -ss  ./img_save/T1_sagittal_085.jpg -noquit
# -viewport axial -slice 127 85 127 -ss  ./img_save/T1_axial_085.jpg -noquit
# -viewport coronal -slice 127 127 85 -ss  ./img_save/T1_coronal_085.jpg -noquit
# -viewport sagittal -slice 86 127 127 -ss  ./img_save/T1_sagittal_086.jpg -noquit
# -viewport axial -slice 127 86 127 -ss  ./img_save/T1_axial_086.jpg -noquit
# -viewport coronal -slice 127 127 86 -ss  ./img_save/T1_coronal_086.jpg -noquit
# -viewport sagittal -slice 87 127 127 -ss  ./img_save/T1_sagittal_087.jpg -noquit
# -viewport axial -slice 127 87 127 -ss  ./img_save/T1_axial_087.jpg -noquit
# -viewport coronal -slice 127 127 87 -ss  ./img_save/T1_coronal_087.jpg -noquit
# -viewport sagittal -slice 88 127 127 -ss  ./img_save/T1_sagittal_088.jpg -noquit
# -viewport axial -slice 127 88 127 -ss  ./img_save/T1_axial_088.jpg -noquit
# -viewport coronal -slice 127 127 88 -ss  ./img_save/T1_coronal_088.jpg -noquit
# -viewport sagittal -slice 89 127 127 -ss  ./img_save/T1_sagittal_089.jpg -noquit
# -viewport axial -slice 127 89 127 -ss  ./img_save/T1_axial_089.jpg -noquit
# -viewport coronal -slice 127 127 89 -ss  ./img_save/T1_coronal_089.jpg -noquit
# -viewport sagittal -slice 90 127 127 -ss  ./img_save/T1_sagittal_090.jpg -noquit
# -viewport axial -slice 127 90 127 -ss  ./img_save/T1_axial_090.jpg -noquit
# -viewport coronal -slice 127 127 90 -ss  ./img_save/T1_coronal_090.jpg -noquit
# -viewport sagittal -slice 91 127 127 -ss  ./img_save/T1_sagittal_091.jpg -noquit
# -viewport axial -slice 127 91 127 -ss  ./img_save/T1_axial_091.jpg -noquit
# -viewport coronal -slice 127 127 91 -ss  ./img_save/T1_coronal_091.jpg -noquit
# -viewport sagittal -slice 92 127 127 -ss  ./img_save/T1_sagittal_092.jpg -noquit
# -viewport axial -slice 127 92 127 -ss  ./img_save/T1_axial_092.jpg -noquit
# -viewport coronal -slice 127 127 92 -ss  ./img_save/T1_coronal_092.jpg -noquit
# -viewport sagittal -slice 93 127 127 -ss  ./img_save/T1_sagittal_093.jpg -noquit
# -viewport axial -slice 127 93 127 -ss  ./img_save/T1_axial_093.jpg -noquit
# -viewport coronal -slice 127 127 93 -ss  ./img_save/T1_coronal_093.jpg -noquit
# -viewport sagittal -slice 94 127 127 -ss  ./img_save/T1_sagittal_094.jpg -noquit
# -viewport axial -slice 127 94 127 -ss  ./img_save/T1_axial_094.jpg -noquit
# -viewport coronal -slice 127 127 94 -ss  ./img_save/T1_coronal_094.jpg -noquit
# -viewport sagittal -slice 95 127 127 -ss  ./img_save/T1_sagittal_095.jpg -noquit
# -viewport axial -slice 127 95 127 -ss  ./img_save/T1_axial_095.jpg -noquit
# -viewport coronal -slice 127 127 95 -ss  ./img_save/T1_coronal_095.jpg -noquit
# -viewport sagittal -slice 96 127 127 -ss  ./img_save/T1_sagittal_096.jpg -noquit
# -viewport axial -slice 127 96 127 -ss  ./img_save/T1_axial_096.jpg -noquit
# -viewport coronal -slice 127 127 96 -ss  ./img_save/T1_coronal_096.jpg -noquit
# -viewport sagittal -slice 97 127 127 -ss  ./img_save/T1_sagittal_097.jpg -noquit
# -viewport axial -slice 127 97 127 -ss  ./img_save/T1_axial_097.jpg -noquit
# -viewport coronal -slice 127 127 97 -ss  ./img_save/T1_coronal_097.jpg -noquit
# -viewport sagittal -slice 98 127 127 -ss  ./img_save/T1_sagittal_098.jpg -noquit
# -viewport axial -slice 127 98 127 -ss  ./img_save/T1_axial_098.jpg -noquit
# -viewport coronal -slice 127 127 98 -ss  ./img_save/T1_coronal_098.jpg -noquit
# -viewport sagittal -slice 99 127 127 -ss  ./img_save/T1_sagittal_099.jpg -noquit
# -viewport axial -slice 127 99 127 -ss  ./img_save/T1_axial_099.jpg -noquit
# -viewport coronal -slice 127 127 99 -ss  ./img_save/T1_coronal_099.jpg -noquit
# -viewport sagittal -slice 100 127 127 -ss  ./img_save/T1_sagittal_100.jpg -noquit
# -viewport axial -slice 127 100 127 -ss  ./img_save/T1_axial_100.jpg -noquit
# -viewport coronal -slice 127 127 100 -ss  ./img_save/T1_coronal_100.jpg -noquit
# -viewport sagittal -slice 101 127 127 -ss  ./img_save/T1_sagittal_101.jpg -noquit
# -viewport axial -slice 127 101 127 -ss  ./img_save/T1_axial_101.jpg -noquit
# -viewport coronal -slice 127 127 101 -ss  ./img_save/T1_coronal_101.jpg -noquit
# -viewport sagittal -slice 102 127 127 -ss  ./img_save/T1_sagittal_102.jpg -noquit
# -viewport axial -slice 127 102 127 -ss  ./img_save/T1_axial_102.jpg -noquit
# -viewport coronal -slice 127 127 102 -ss  ./img_save/T1_coronal_102.jpg -noquit
# -viewport sagittal -slice 103 127 127 -ss  ./img_save/T1_sagittal_103.jpg -noquit
# -viewport axial -slice 127 103 127 -ss  ./img_save/T1_axial_103.jpg -noquit
# -viewport coronal -slice 127 127 103 -ss  ./img_save/T1_coronal_103.jpg -noquit
# -viewport sagittal -slice 104 127 127 -ss  ./img_save/T1_sagittal_104.jpg -noquit
# -viewport axial -slice 127 104 127 -ss  ./img_save/T1_axial_104.jpg -noquit
# -viewport coronal -slice 127 127 104 -ss  ./img_save/T1_coronal_104.jpg -noquit
# -viewport sagittal -slice 105 127 127 -ss  ./img_save/T1_sagittal_105.jpg -noquit
# -viewport axial -slice 127 105 127 -ss  ./img_save/T1_axial_105.jpg -noquit
# -viewport coronal -slice 127 127 105 -ss  ./img_save/T1_coronal_105.jpg -noquit
# -viewport sagittal -slice 106 127 127 -ss  ./img_save/T1_sagittal_106.jpg -noquit
# -viewport axial -slice 127 106 127 -ss  ./img_save/T1_axial_106.jpg -noquit
# -viewport coronal -slice 127 127 106 -ss  ./img_save/T1_coronal_106.jpg -noquit
# -viewport sagittal -slice 107 127 127 -ss  ./img_save/T1_sagittal_107.jpg -noquit
# -viewport axial -slice 127 107 127 -ss  ./img_save/T1_axial_107.jpg -noquit
# -viewport coronal -slice 127 127 107 -ss  ./img_save/T1_coronal_107.jpg -noquit
# -viewport sagittal -slice 108 127 127 -ss  ./img_save/T1_sagittal_108.jpg -noquit
# -viewport axial -slice 127 108 127 -ss  ./img_save/T1_axial_108.jpg -noquit
# -viewport coronal -slice 127 127 108 -ss  ./img_save/T1_coronal_108.jpg -noquit
# -viewport sagittal -slice 109 127 127 -ss  ./img_save/T1_sagittal_109.jpg -noquit
# -viewport axial -slice 127 109 127 -ss  ./img_save/T1_axial_109.jpg -noquit
# -viewport coronal -slice 127 127 109 -ss  ./img_save/T1_coronal_109.jpg -noquit
# -viewport sagittal -slice 110 127 127 -ss  ./img_save/T1_sagittal_110.jpg -noquit
# -viewport axial -slice 127 110 127 -ss  ./img_save/T1_axial_110.jpg -noquit
# -viewport coronal -slice 127 127 110 -ss  ./img_save/T1_coronal_110.jpg -noquit
# -viewport sagittal -slice 111 127 127 -ss  ./img_save/T1_sagittal_111.jpg -noquit
# -viewport axial -slice 127 111 127 -ss  ./img_save/T1_axial_111.jpg -noquit
# -viewport coronal -slice 127 127 111 -ss  ./img_save/T1_coronal_111.jpg -noquit
# -viewport sagittal -slice 112 127 127 -ss  ./img_save/T1_sagittal_112.jpg -noquit
# -viewport axial -slice 127 112 127 -ss  ./img_save/T1_axial_112.jpg -noquit
# -viewport coronal -slice 127 127 112 -ss  ./img_save/T1_coronal_112.jpg -noquit
# -viewport sagittal -slice 113 127 127 -ss  ./img_save/T1_sagittal_113.jpg -noquit
# -viewport axial -slice 127 113 127 -ss  ./img_save/T1_axial_113.jpg -noquit
# -viewport coronal -slice 127 127 113 -ss  ./img_save/T1_coronal_113.jpg -noquit
# -viewport sagittal -slice 114 127 127 -ss  ./img_save/T1_sagittal_114.jpg -noquit
# -viewport axial -slice 127 114 127 -ss  ./img_save/T1_axial_114.jpg -noquit
# -viewport coronal -slice 127 127 114 -ss  ./img_save/T1_coronal_114.jpg -noquit
# -viewport sagittal -slice 115 127 127 -ss  ./img_save/T1_sagittal_115.jpg -noquit
# -viewport axial -slice 127 115 127 -ss  ./img_save/T1_axial_115.jpg -noquit
# -viewport coronal -slice 127 127 115 -ss  ./img_save/T1_coronal_115.jpg -noquit
# -viewport sagittal -slice 116 127 127 -ss  ./img_save/T1_sagittal_116.jpg -noquit
# -viewport axial -slice 127 116 127 -ss  ./img_save/T1_axial_116.jpg -noquit
# -viewport coronal -slice 127 127 116 -ss  ./img_save/T1_coronal_116.jpg -noquit
# -viewport sagittal -slice 117 127 127 -ss  ./img_save/T1_sagittal_117.jpg -noquit
# -viewport axial -slice 127 117 127 -ss  ./img_save/T1_axial_117.jpg -noquit
# -viewport coronal -slice 127 127 117 -ss  ./img_save/T1_coronal_117.jpg -noquit
# -viewport sagittal -slice 118 127 127 -ss  ./img_save/T1_sagittal_118.jpg -noquit
# -viewport axial -slice 127 118 127 -ss  ./img_save/T1_axial_118.jpg -noquit
# -viewport coronal -slice 127 127 118 -ss  ./img_save/T1_coronal_118.jpg -noquit
# -viewport sagittal -slice 119 127 127 -ss  ./img_save/T1_sagittal_119.jpg -noquit
# -viewport axial -slice 127 119 127 -ss  ./img_save/T1_axial_119.jpg -noquit
# -viewport coronal -slice 127 127 119 -ss  ./img_save/T1_coronal_119.jpg -noquit
# -viewport sagittal -slice 120 127 127 -ss  ./img_save/T1_sagittal_120.jpg -noquit
# -viewport axial -slice 127 120 127 -ss  ./img_save/T1_axial_120.jpg -noquit
# -viewport coronal -slice 127 127 120 -ss  ./img_save/T1_coronal_120.jpg -noquit
# -viewport sagittal -slice 121 127 127 -ss  ./img_save/T1_sagittal_121.jpg -noquit
# -viewport axial -slice 127 121 127 -ss  ./img_save/T1_axial_121.jpg -noquit
# -viewport coronal -slice 127 127 121 -ss  ./img_save/T1_coronal_121.jpg -noquit
# -viewport sagittal -slice 122 127 127 -ss  ./img_save/T1_sagittal_122.jpg -noquit
# -viewport axial -slice 127 122 127 -ss  ./img_save/T1_axial_122.jpg -noquit
# -viewport coronal -slice 127 127 122 -ss  ./img_save/T1_coronal_122.jpg -noquit
# -viewport sagittal -slice 123 127 127 -ss  ./img_save/T1_sagittal_123.jpg -noquit
# -viewport axial -slice 127 123 127 -ss  ./img_save/T1_axial_123.jpg -noquit
# -viewport coronal -slice 127 127 123 -ss  ./img_save/T1_coronal_123.jpg -noquit
# -viewport sagittal -slice 124 127 127 -ss  ./img_save/T1_sagittal_124.jpg -noquit
# -viewport axial -slice 127 124 127 -ss  ./img_save/T1_axial_124.jpg -noquit
# -viewport coronal -slice 127 127 124 -ss  ./img_save/T1_coronal_124.jpg -noquit
# -viewport sagittal -slice 125 127 127 -ss  ./img_save/T1_sagittal_125.jpg -noquit
# -viewport axial -slice 127 125 127 -ss  ./img_save/T1_axial_125.jpg -noquit
# -viewport coronal -slice 127 127 125 -ss  ./img_save/T1_coronal_125.jpg -noquit
# -viewport sagittal -slice 126 127 127 -ss  ./img_save/T1_sagittal_126.jpg -noquit
# -viewport axial -slice 127 126 127 -ss  ./img_save/T1_axial_126.jpg -noquit
# -viewport coronal -slice 127 127 126 -ss  ./img_save/T1_coronal_126.jpg -noquit
# -viewport sagittal -slice 127 127 127 -ss  ./img_save/T1_sagittal_127.jpg -noquit
# -viewport axial -slice 127 127 127 -ss  ./img_save/T1_axial_127.jpg -noquit
# -viewport coronal -slice 127 127 127 -ss  ./img_save/T1_coronal_127.jpg -noquit
# -viewport sagittal -slice 128 127 127 -ss  ./img_save/T1_sagittal_128.jpg -noquit
# -viewport axial -slice 127 128 127 -ss  ./img_save/T1_axial_128.jpg -noquit
# -viewport coronal -slice 127 127 128 -ss  ./img_save/T1_coronal_128.jpg -noquit
# -viewport sagittal -slice 129 127 127 -ss  ./img_save/T1_sagittal_129.jpg -noquit
# -viewport axial -slice 127 129 127 -ss  ./img_save/T1_axial_129.jpg -noquit
# -viewport coronal -slice 127 127 129 -ss  ./img_save/T1_coronal_129.jpg -noquit
# -viewport sagittal -slice 130 127 127 -ss  ./img_save/T1_sagittal_130.jpg -noquit
# -viewport axial -slice 127 130 127 -ss  ./img_save/T1_axial_130.jpg -noquit
# -viewport coronal -slice 127 127 130 -ss  ./img_save/T1_coronal_130.jpg -noquit
# -viewport sagittal -slice 131 127 127 -ss  ./img_save/T1_sagittal_131.jpg -noquit
# -viewport axial -slice 127 131 127 -ss  ./img_save/T1_axial_131.jpg -noquit
# -viewport coronal -slice 127 127 131 -ss  ./img_save/T1_coronal_131.jpg -noquit
# -viewport sagittal -slice 132 127 127 -ss  ./img_save/T1_sagittal_132.jpg -noquit
# -viewport axial -slice 127 132 127 -ss  ./img_save/T1_axial_132.jpg -noquit
# -viewport coronal -slice 127 127 132 -ss  ./img_save/T1_coronal_132.jpg -noquit
# -viewport sagittal -slice 133 127 127 -ss  ./img_save/T1_sagittal_133.jpg -noquit
# -viewport axial -slice 127 133 127 -ss  ./img_save/T1_axial_133.jpg -noquit
# -viewport coronal -slice 127 127 133 -ss  ./img_save/T1_coronal_133.jpg -noquit
# -viewport sagittal -slice 134 127 127 -ss  ./img_save/T1_sagittal_134.jpg -noquit
# -viewport axial -slice 127 134 127 -ss  ./img_save/T1_axial_134.jpg -noquit
# -viewport coronal -slice 127 127 134 -ss  ./img_save/T1_coronal_134.jpg -noquit
# -viewport sagittal -slice 135 127 127 -ss  ./img_save/T1_sagittal_135.jpg -noquit
# -viewport axial -slice 127 135 127 -ss  ./img_save/T1_axial_135.jpg -noquit
# -viewport coronal -slice 127 127 135 -ss  ./img_save/T1_coronal_135.jpg -noquit
# -viewport sagittal -slice 136 127 127 -ss  ./img_save/T1_sagittal_136.jpg -noquit
# -viewport axial -slice 127 136 127 -ss  ./img_save/T1_axial_136.jpg -noquit
# -viewport coronal -slice 127 127 136 -ss  ./img_save/T1_coronal_136.jpg -noquit
# -viewport sagittal -slice 137 127 127 -ss  ./img_save/T1_sagittal_137.jpg -noquit
# -viewport axial -slice 127 137 127 -ss  ./img_save/T1_axial_137.jpg -noquit
# -viewport coronal -slice 127 127 137 -ss  ./img_save/T1_coronal_137.jpg -noquit
# -viewport sagittal -slice 138 127 127 -ss  ./img_save/T1_sagittal_138.jpg -noquit
# -viewport axial -slice 127 138 127 -ss  ./img_save/T1_axial_138.jpg -noquit
# -viewport coronal -slice 127 127 138 -ss  ./img_save/T1_coronal_138.jpg -noquit
# -viewport sagittal -slice 139 127 127 -ss  ./img_save/T1_sagittal_139.jpg -noquit
# -viewport axial -slice 127 139 127 -ss  ./img_save/T1_axial_139.jpg -noquit
# -viewport coronal -slice 127 127 139 -ss  ./img_save/T1_coronal_139.jpg -noquit
# -viewport sagittal -slice 140 127 127 -ss  ./img_save/T1_sagittal_140.jpg -noquit
# -viewport axial -slice 127 140 127 -ss  ./img_save/T1_axial_140.jpg -noquit
# -viewport coronal -slice 127 127 140 -ss  ./img_save/T1_coronal_140.jpg -noquit
# -viewport sagittal -slice 141 127 127 -ss  ./img_save/T1_sagittal_141.jpg -noquit
# -viewport axial -slice 127 141 127 -ss  ./img_save/T1_axial_141.jpg -noquit
# -viewport coronal -slice 127 127 141 -ss  ./img_save/T1_coronal_141.jpg -noquit
# -viewport sagittal -slice 142 127 127 -ss  ./img_save/T1_sagittal_142.jpg -noquit
# -viewport axial -slice 127 142 127 -ss  ./img_save/T1_axial_142.jpg -noquit
# -viewport coronal -slice 127 127 142 -ss  ./img_save/T1_coronal_142.jpg -noquit
# -viewport sagittal -slice 143 127 127 -ss  ./img_save/T1_sagittal_143.jpg -noquit
# -viewport axial -slice 127 143 127 -ss  ./img_save/T1_axial_143.jpg -noquit
# -viewport coronal -slice 127 127 143 -ss  ./img_save/T1_coronal_143.jpg -noquit
# -viewport sagittal -slice 144 127 127 -ss  ./img_save/T1_sagittal_144.jpg -noquit
# -viewport axial -slice 127 144 127 -ss  ./img_save/T1_axial_144.jpg -noquit
# -viewport coronal -slice 127 127 144 -ss  ./img_save/T1_coronal_144.jpg -noquit
# -viewport sagittal -slice 145 127 127 -ss  ./img_save/T1_sagittal_145.jpg -noquit
# -viewport axial -slice 127 145 127 -ss  ./img_save/T1_axial_145.jpg -noquit
# -viewport coronal -slice 127 127 145 -ss  ./img_save/T1_coronal_145.jpg -noquit
# -viewport sagittal -slice 146 127 127 -ss  ./img_save/T1_sagittal_146.jpg -noquit
# -viewport axial -slice 127 146 127 -ss  ./img_save/T1_axial_146.jpg -noquit
# -viewport coronal -slice 127 127 146 -ss  ./img_save/T1_coronal_146.jpg -noquit
# -viewport sagittal -slice 147 127 127 -ss  ./img_save/T1_sagittal_147.jpg -noquit
# -viewport axial -slice 127 147 127 -ss  ./img_save/T1_axial_147.jpg -noquit
# -viewport coronal -slice 127 127 147 -ss  ./img_save/T1_coronal_147.jpg -noquit
# -viewport sagittal -slice 148 127 127 -ss  ./img_save/T1_sagittal_148.jpg -noquit
# -viewport axial -slice 127 148 127 -ss  ./img_save/T1_axial_148.jpg -noquit
# -viewport coronal -slice 127 127 148 -ss  ./img_save/T1_coronal_148.jpg -noquit
# -viewport sagittal -slice 149 127 127 -ss  ./img_save/T1_sagittal_149.jpg -noquit
# -viewport axial -slice 127 149 127 -ss  ./img_save/T1_axial_149.jpg -noquit
# -viewport coronal -slice 127 127 149 -ss  ./img_save/T1_coronal_149.jpg -noquit
# -viewport sagittal -slice 150 127 127 -ss  ./img_save/T1_sagittal_150.jpg -noquit
# -viewport axial -slice 127 150 127 -ss  ./img_save/T1_axial_150.jpg -noquit
# -viewport coronal -slice 127 127 150 -ss  ./img_save/T1_coronal_150.jpg -noquit
# -viewport sagittal -slice 151 127 127 -ss  ./img_save/T1_sagittal_151.jpg -noquit
# -viewport axial -slice 127 151 127 -ss  ./img_save/T1_axial_151.jpg -noquit
# -viewport coronal -slice 127 127 151 -ss  ./img_save/T1_coronal_151.jpg -noquit
# -viewport sagittal -slice 152 127 127 -ss  ./img_save/T1_sagittal_152.jpg -noquit
# -viewport axial -slice 127 152 127 -ss  ./img_save/T1_axial_152.jpg -noquit
# -viewport coronal -slice 127 127 152 -ss  ./img_save/T1_coronal_152.jpg -noquit
# -viewport sagittal -slice 153 127 127 -ss  ./img_save/T1_sagittal_153.jpg -noquit
# -viewport axial -slice 127 153 127 -ss  ./img_save/T1_axial_153.jpg -noquit
# -viewport coronal -slice 127 127 153 -ss  ./img_save/T1_coronal_153.jpg -noquit
# -viewport sagittal -slice 154 127 127 -ss  ./img_save/T1_sagittal_154.jpg -noquit
# -viewport axial -slice 127 154 127 -ss  ./img_save/T1_axial_154.jpg -noquit
# -viewport coronal -slice 127 127 154 -ss  ./img_save/T1_coronal_154.jpg -noquit
# -viewport sagittal -slice 155 127 127 -ss  ./img_save/T1_sagittal_155.jpg -noquit
# -viewport axial -slice 127 155 127 -ss  ./img_save/T1_axial_155.jpg -noquit
# -viewport coronal -slice 127 127 155 -ss  ./img_save/T1_coronal_155.jpg -noquit
# -viewport sagittal -slice 156 127 127 -ss  ./img_save/T1_sagittal_156.jpg -noquit
# -viewport axial -slice 127 156 127 -ss  ./img_save/T1_axial_156.jpg -noquit
# -viewport coronal -slice 127 127 156 -ss  ./img_save/T1_coronal_156.jpg -noquit
# -viewport sagittal -slice 157 127 127 -ss  ./img_save/T1_sagittal_157.jpg -noquit
# -viewport axial -slice 127 157 127 -ss  ./img_save/T1_axial_157.jpg -noquit
# -viewport coronal -slice 127 127 157 -ss  ./img_save/T1_coronal_157.jpg -noquit
# -viewport sagittal -slice 158 127 127 -ss  ./img_save/T1_sagittal_158.jpg -noquit
# -viewport axial -slice 127 158 127 -ss  ./img_save/T1_axial_158.jpg -noquit
# -viewport coronal -slice 127 127 158 -ss  ./img_save/T1_coronal_158.jpg -noquit
# -viewport sagittal -slice 159 127 127 -ss  ./img_save/T1_sagittal_159.jpg -noquit
# -viewport axial -slice 127 159 127 -ss  ./img_save/T1_axial_159.jpg -noquit
# -viewport coronal -slice 127 127 159 -ss  ./img_save/T1_coronal_159.jpg -noquit
# -viewport sagittal -slice 160 127 127 -ss  ./img_save/T1_sagittal_160.jpg -noquit
# -viewport axial -slice 127 160 127 -ss  ./img_save/T1_axial_160.jpg -noquit
# -viewport coronal -slice 127 127 160 -ss  ./img_save/T1_coronal_160.jpg -noquit
# -viewport sagittal -slice 161 127 127 -ss  ./img_save/T1_sagittal_161.jpg -noquit
# -viewport axial -slice 127 161 127 -ss  ./img_save/T1_axial_161.jpg -noquit
# -viewport coronal -slice 127 127 161 -ss  ./img_save/T1_coronal_161.jpg -noquit
# -viewport sagittal -slice 162 127 127 -ss  ./img_save/T1_sagittal_162.jpg -noquit
# -viewport axial -slice 127 162 127 -ss  ./img_save/T1_axial_162.jpg -noquit
# -viewport coronal -slice 127 127 162 -ss  ./img_save/T1_coronal_162.jpg -noquit
# -viewport sagittal -slice 163 127 127 -ss  ./img_save/T1_sagittal_163.jpg -noquit
# -viewport axial -slice 127 163 127 -ss  ./img_save/T1_axial_163.jpg -noquit
# -viewport coronal -slice 127 127 163 -ss  ./img_save/T1_coronal_163.jpg -noquit
# -viewport sagittal -slice 164 127 127 -ss  ./img_save/T1_sagittal_164.jpg -noquit
# -viewport axial -slice 127 164 127 -ss  ./img_save/T1_axial_164.jpg -noquit
# -viewport coronal -slice 127 127 164 -ss  ./img_save/T1_coronal_164.jpg -noquit
# -viewport sagittal -slice 165 127 127 -ss  ./img_save/T1_sagittal_165.jpg -noquit
# -viewport axial -slice 127 165 127 -ss  ./img_save/T1_axial_165.jpg -noquit
# -viewport coronal -slice 127 127 165 -ss  ./img_save/T1_coronal_165.jpg -noquit
# -viewport sagittal -slice 166 127 127 -ss  ./img_save/T1_sagittal_166.jpg -noquit
# -viewport axial -slice 127 166 127 -ss  ./img_save/T1_axial_166.jpg -noquit
# -viewport coronal -slice 127 127 166 -ss  ./img_save/T1_coronal_166.jpg -noquit
# -viewport sagittal -slice 167 127 127 -ss  ./img_save/T1_sagittal_167.jpg -noquit
# -viewport axial -slice 127 167 127 -ss  ./img_save/T1_axial_167.jpg -noquit
# -viewport coronal -slice 127 127 167 -ss  ./img_save/T1_coronal_167.jpg -noquit
# -viewport sagittal -slice 168 127 127 -ss  ./img_save/T1_sagittal_168.jpg -noquit
# -viewport axial -slice 127 168 127 -ss  ./img_save/T1_axial_168.jpg -noquit
# -viewport coronal -slice 127 127 168 -ss  ./img_save/T1_coronal_168.jpg -noquit
# -viewport sagittal -slice 169 127 127 -ss  ./img_save/T1_sagittal_169.jpg -noquit
# -viewport axial -slice 127 169 127 -ss  ./img_save/T1_axial_169.jpg -noquit
# -viewport coronal -slice 127 127 169 -ss  ./img_save/T1_coronal_169.jpg -noquit
# -viewport sagittal -slice 170 127 127 -ss  ./img_save/T1_sagittal_170.jpg -noquit
# -viewport axial -slice 127 170 127 -ss  ./img_save/T1_axial_170.jpg -noquit
# -viewport coronal -slice 127 127 170 -ss  ./img_save/T1_coronal_170.jpg -noquit
# -viewport sagittal -slice 171 127 127 -ss  ./img_save/T1_sagittal_171.jpg -noquit
# -viewport axial -slice 127 171 127 -ss  ./img_save/T1_axial_171.jpg -noquit
# -viewport coronal -slice 127 127 171 -ss  ./img_save/T1_coronal_171.jpg -noquit
# -viewport sagittal -slice 172 127 127 -ss  ./img_save/T1_sagittal_172.jpg -noquit
# -viewport axial -slice 127 172 127 -ss  ./img_save/T1_axial_172.jpg -noquit
# -viewport coronal -slice 127 127 172 -ss  ./img_save/T1_coronal_172.jpg -noquit
# -viewport sagittal -slice 173 127 127 -ss  ./img_save/T1_sagittal_173.jpg -noquit
# -viewport axial -slice 127 173 127 -ss  ./img_save/T1_axial_173.jpg -noquit
# -viewport coronal -slice 127 127 173 -ss  ./img_save/T1_coronal_173.jpg -noquit
# -viewport sagittal -slice 174 127 127 -ss  ./img_save/T1_sagittal_174.jpg -noquit
# -viewport axial -slice 127 174 127 -ss  ./img_save/T1_axial_174.jpg -noquit
# -viewport coronal -slice 127 127 174 -ss  ./img_save/T1_coronal_174.jpg -noquit
# -viewport sagittal -slice 175 127 127 -ss  ./img_save/T1_sagittal_175.jpg -noquit
# -viewport axial -slice 127 175 127 -ss  ./img_save/T1_axial_175.jpg -noquit
# -viewport coronal -slice 127 127 175 -ss  ./img_save/T1_coronal_175.jpg -noquit
# -viewport sagittal -slice 176 127 127 -ss  ./img_save/T1_sagittal_176.jpg -noquit
# -viewport axial -slice 127 176 127 -ss  ./img_save/T1_axial_176.jpg -noquit
# -viewport coronal -slice 127 127 176 -ss  ./img_save/T1_coronal_176.jpg -noquit
# -viewport sagittal -slice 177 127 127 -ss  ./img_save/T1_sagittal_177.jpg -noquit
# -viewport axial -slice 127 177 127 -ss  ./img_save/T1_axial_177.jpg -noquit
# -viewport coronal -slice 127 127 177 -ss  ./img_save/T1_coronal_177.jpg -noquit
# -viewport sagittal -slice 178 127 127 -ss  ./img_save/T1_sagittal_178.jpg -noquit
# -viewport axial -slice 127 178 127 -ss  ./img_save/T1_axial_178.jpg -noquit
# -viewport coronal -slice 127 127 178 -ss  ./img_save/T1_coronal_178.jpg -noquit
# -viewport sagittal -slice 179 127 127 -ss  ./img_save/T1_sagittal_179.jpg -noquit
# -viewport axial -slice 127 179 127 -ss  ./img_save/T1_axial_179.jpg -noquit
# -viewport coronal -slice 127 127 179 -ss  ./img_save/T1_coronal_179.jpg -noquit
# -viewport sagittal -slice 180 127 127 -ss  ./img_save/T1_sagittal_180.jpg -noquit
# -viewport axial -slice 127 180 127 -ss  ./img_save/T1_axial_180.jpg -noquit
# -viewport coronal -slice 127 127 180 -ss  ./img_save/T1_coronal_180.jpg -noquit
# -viewport sagittal -slice 181 127 127 -ss  ./img_save/T1_sagittal_181.jpg -noquit
# -viewport axial -slice 127 181 127 -ss  ./img_save/T1_axial_181.jpg -noquit
# -viewport coronal -slice 127 127 181 -ss  ./img_save/T1_coronal_181.jpg -noquit
# -viewport sagittal -slice 182 127 127 -ss  ./img_save/T1_sagittal_182.jpg -noquit
# -viewport axial -slice 127 182 127 -ss  ./img_save/T1_axial_182.jpg -noquit
# -viewport coronal -slice 127 127 182 -ss  ./img_save/T1_coronal_182.jpg -noquit
# -viewport sagittal -slice 183 127 127 -ss  ./img_save/T1_sagittal_183.jpg -noquit
# -viewport axial -slice 127 183 127 -ss  ./img_save/T1_axial_183.jpg -noquit
# -viewport coronal -slice 127 127 183 -ss  ./img_save/T1_coronal_183.jpg -noquit
# -viewport sagittal -slice 184 127 127 -ss  ./img_save/T1_sagittal_184.jpg -noquit
# -viewport axial -slice 127 184 127 -ss  ./img_save/T1_axial_184.jpg -noquit
# -viewport coronal -slice 127 127 184 -ss  ./img_save/T1_coronal_184.jpg -noquit
# -viewport sagittal -slice 185 127 127 -ss  ./img_save/T1_sagittal_185.jpg -noquit
# -viewport axial -slice 127 185 127 -ss  ./img_save/T1_axial_185.jpg -noquit
# -viewport coronal -slice 127 127 185 -ss  ./img_save/T1_coronal_185.jpg -noquit
# -viewport sagittal -slice 186 127 127 -ss  ./img_save/T1_sagittal_186.jpg -noquit
# -viewport axial -slice 127 186 127 -ss  ./img_save/T1_axial_186.jpg -noquit
# -viewport coronal -slice 127 127 186 -ss  ./img_save/T1_coronal_186.jpg -noquit
# -viewport sagittal -slice 187 127 127 -ss  ./img_save/T1_sagittal_187.jpg -noquit
# -viewport axial -slice 127 187 127 -ss  ./img_save/T1_axial_187.jpg -noquit
# -viewport coronal -slice 127 127 187 -ss  ./img_save/T1_coronal_187.jpg -noquit
# -viewport sagittal -slice 188 127 127 -ss  ./img_save/T1_sagittal_188.jpg -noquit
# -viewport axial -slice 127 188 127 -ss  ./img_save/T1_axial_188.jpg -noquit
# -viewport coronal -slice 127 127 188 -ss  ./img_save/T1_coronal_188.jpg -noquit
# -viewport sagittal -slice 189 127 127 -ss  ./img_save/T1_sagittal_189.jpg -noquit
# -viewport axial -slice 127 189 127 -ss  ./img_save/T1_axial_189.jpg -noquit
# -viewport coronal -slice 127 127 189 -ss  ./img_save/T1_coronal_189.jpg -noquit
# -viewport sagittal -slice 190 127 127 -ss  ./img_save/T1_sagittal_190.jpg -noquit
# -viewport axial -slice 127 190 127 -ss  ./img_save/T1_axial_190.jpg -noquit
# -viewport coronal -slice 127 127 190 -ss  ./img_save/T1_coronal_190.jpg -noquit
# -viewport sagittal -slice 191 127 127 -ss  ./img_save/T1_sagittal_191.jpg -noquit
# -viewport axial -slice 127 191 127 -ss  ./img_save/T1_axial_191.jpg -noquit
# -viewport coronal -slice 127 127 191 -ss  ./img_save/T1_coronal_191.jpg -noquit
# -viewport sagittal -slice 192 127 127 -ss  ./img_save/T1_sagittal_192.jpg -noquit
# -viewport axial -slice 127 192 127 -ss  ./img_save/T1_axial_192.jpg -noquit
# -viewport coronal -slice 127 127 192 -ss  ./img_save/T1_coronal_192.jpg -noquit
# -viewport sagittal -slice 193 127 127 -ss  ./img_save/T1_sagittal_193.jpg -noquit
# -viewport axial -slice 127 193 127 -ss  ./img_save/T1_axial_193.jpg -noquit
# -viewport coronal -slice 127 127 193 -ss  ./img_save/T1_coronal_193.jpg -noquit
# -viewport sagittal -slice 194 127 127 -ss  ./img_save/T1_sagittal_194.jpg -noquit
# -viewport axial -slice 127 194 127 -ss  ./img_save/T1_axial_194.jpg -noquit
# -viewport coronal -slice 127 127 194 -ss  ./img_save/T1_coronal_194.jpg -noquit
# -viewport sagittal -slice 195 127 127 -ss  ./img_save/T1_sagittal_195.jpg -noquit
# -viewport axial -slice 127 195 127 -ss  ./img_save/T1_axial_195.jpg -noquit
# -viewport coronal -slice 127 127 195 -ss  ./img_save/T1_coronal_195.jpg -noquit
# -viewport sagittal -slice 196 127 127 -ss  ./img_save/T1_sagittal_196.jpg -noquit
# -viewport axial -slice 127 196 127 -ss  ./img_save/T1_axial_196.jpg -noquit
# -viewport coronal -slice 127 127 196 -ss  ./img_save/T1_coronal_196.jpg -noquit
# -viewport sagittal -slice 197 127 127 -ss  ./img_save/T1_sagittal_197.jpg -noquit
# -viewport axial -slice 127 197 127 -ss  ./img_save/T1_axial_197.jpg -noquit
# -viewport coronal -slice 127 127 197 -ss  ./img_save/T1_coronal_197.jpg -noquit
# -viewport sagittal -slice 198 127 127 -ss  ./img_save/T1_sagittal_198.jpg -noquit
# -viewport axial -slice 127 198 127 -ss  ./img_save/T1_axial_198.jpg -noquit
# -viewport coronal -slice 127 127 198 -ss  ./img_save/T1_coronal_198.jpg -noquit
# -viewport sagittal -slice 199 127 127 -ss  ./img_save/T1_sagittal_199.jpg -noquit
# -viewport axial -slice 127 199 127 -ss  ./img_save/T1_axial_199.jpg -noquit
# -viewport coronal -slice 127 127 199 -ss  ./img_save/T1_coronal_199.jpg -noquit
# -viewport sagittal -slice 200 127 127 -ss  ./img_save/T1_sagittal_200.jpg -noquit
# -viewport axial -slice 127 200 127 -ss  ./img_save/T1_axial_200.jpg -noquit
# -viewport coronal -slice 127 127 200 -ss  ./img_save/T1_coronal_200.jpg -noquit
# -viewport sagittal -slice 201 127 127 -ss  ./img_save/T1_sagittal_201.jpg -noquit
# -viewport axial -slice 127 201 127 -ss  ./img_save/T1_axial_201.jpg -noquit
# -viewport coronal -slice 127 127 201 -ss  ./img_save/T1_coronal_201.jpg -noquit
# -viewport sagittal -slice 202 127 127 -ss  ./img_save/T1_sagittal_202.jpg -noquit
# -viewport axial -slice 127 202 127 -ss  ./img_save/T1_axial_202.jpg -noquit
# -viewport coronal -slice 127 127 202 -ss  ./img_save/T1_coronal_202.jpg -noquit
# -viewport sagittal -slice 203 127 127 -ss  ./img_save/T1_sagittal_203.jpg -noquit
# -viewport axial -slice 127 203 127 -ss  ./img_save/T1_axial_203.jpg -noquit
# -viewport coronal -slice 127 127 203 -ss  ./img_save/T1_coronal_203.jpg -noquit
# -viewport sagittal -slice 204 127 127 -ss  ./img_save/T1_sagittal_204.jpg -noquit
# -viewport axial -slice 127 204 127 -ss  ./img_save/T1_axial_204.jpg -noquit
# -viewport coronal -slice 127 127 204 -ss  ./img_save/T1_coronal_204.jpg -noquit
# -viewport sagittal -slice 205 127 127 -ss  ./img_save/T1_sagittal_205.jpg -noquit
# -viewport axial -slice 127 205 127 -ss  ./img_save/T1_axial_205.jpg -noquit
# -viewport coronal -slice 127 127 205 -ss  ./img_save/T1_coronal_205.jpg -noquit
# -viewport sagittal -slice 206 127 127 -ss  ./img_save/T1_sagittal_206.jpg -noquit
# -viewport axial -slice 127 206 127 -ss  ./img_save/T1_axial_206.jpg -noquit
# -viewport coronal -slice 127 127 206 -ss  ./img_save/T1_coronal_206.jpg -noquit
# -viewport sagittal -slice 207 127 127 -ss  ./img_save/T1_sagittal_207.jpg -noquit
# -viewport axial -slice 127 207 127 -ss  ./img_save/T1_axial_207.jpg -noquit
# -viewport coronal -slice 127 127 207 -ss  ./img_save/T1_coronal_207.jpg -noquit
# -viewport sagittal -slice 208 127 127 -ss  ./img_save/T1_sagittal_208.jpg -noquit
# -viewport axial -slice 127 208 127 -ss  ./img_save/T1_axial_208.jpg -noquit
# -viewport coronal -slice 127 127 208 -ss  ./img_save/T1_coronal_208.jpg -noquit
# -viewport sagittal -slice 209 127 127 -ss  ./img_save/T1_sagittal_209.jpg -noquit
# -viewport axial -slice 127 209 127 -ss  ./img_save/T1_axial_209.jpg -noquit
# -viewport coronal -slice 127 127 209 -ss  ./img_save/T1_coronal_209.jpg -noquit
# -viewport sagittal -slice 210 127 127 -ss  ./img_save/T1_sagittal_210.jpg -noquit
# -viewport axial -slice 127 210 127 -ss  ./img_save/T1_axial_210.jpg -noquit
# -viewport coronal -slice 127 127 210 -ss  ./img_save/T1_coronal_210.jpg -noquit
# -viewport sagittal -slice 211 127 127 -ss  ./img_save/T1_sagittal_211.jpg -noquit
# -viewport axial -slice 127 211 127 -ss  ./img_save/T1_axial_211.jpg -noquit
# -viewport coronal -slice 127 127 211 -ss  ./img_save/T1_coronal_211.jpg -noquit
# -viewport sagittal -slice 212 127 127 -ss  ./img_save/T1_sagittal_212.jpg -noquit
# -viewport axial -slice 127 212 127 -ss  ./img_save/T1_axial_212.jpg -noquit
# -viewport coronal -slice 127 127 212 -ss  ./img_save/T1_coronal_212.jpg -noquit
# -viewport sagittal -slice 213 127 127 -ss  ./img_save/T1_sagittal_213.jpg -noquit
# -viewport axial -slice 127 213 127 -ss  ./img_save/T1_axial_213.jpg -noquit
# -viewport coronal -slice 127 127 213 -ss  ./img_save/T1_coronal_213.jpg -noquit
# -viewport sagittal -slice 214 127 127 -ss  ./img_save/T1_sagittal_214.jpg -noquit
# -viewport axial -slice 127 214 127 -ss  ./img_save/T1_axial_214.jpg -noquit
# -viewport coronal -slice 127 127 214 -ss  ./img_save/T1_coronal_214.jpg -noquit
# -viewport sagittal -slice 215 127 127 -ss  ./img_save/T1_sagittal_215.jpg -noquit
# -viewport axial -slice 127 215 127 -ss  ./img_save/T1_axial_215.jpg -noquit
# -viewport coronal -slice 127 127 215 -ss  ./img_save/T1_coronal_215.jpg -noquit
# -viewport sagittal -slice 216 127 127 -ss  ./img_save/T1_sagittal_216.jpg -noquit
# -viewport axial -slice 127 216 127 -ss  ./img_save/T1_axial_216.jpg -noquit
# -viewport coronal -slice 127 127 216 -ss  ./img_save/T1_coronal_216.jpg -noquit
# -viewport sagittal -slice 217 127 127 -ss  ./img_save/T1_sagittal_217.jpg -noquit
# -viewport axial -slice 127 217 127 -ss  ./img_save/T1_axial_217.jpg -noquit
# -viewport coronal -slice 127 127 217 -ss  ./img_save/T1_coronal_217.jpg -noquit
# -viewport sagittal -slice 218 127 127 -ss  ./img_save/T1_sagittal_218.jpg -noquit
# -viewport axial -slice 127 218 127 -ss  ./img_save/T1_axial_218.jpg -noquit
# -viewport coronal -slice 127 127 218 -ss  ./img_save/T1_coronal_218.jpg -noquit
# -viewport sagittal -slice 219 127 127 -ss  ./img_save/T1_sagittal_219.jpg -noquit
# -viewport axial -slice 127 219 127 -ss  ./img_save/T1_axial_219.jpg -noquit
# -viewport coronal -slice 127 127 219 -ss  ./img_save/T1_coronal_219.jpg -noquit
# -viewport sagittal -slice 220 127 127 -ss  ./img_save/T1_sagittal_220.jpg -noquit
# -viewport axial -slice 127 220 127 -ss  ./img_save/T1_axial_220.jpg -noquit
# -viewport coronal -slice 127 127 220 -ss  ./img_save/T1_coronal_220.jpg -noquit
# -viewport sagittal -slice 221 127 127 -ss  ./img_save/T1_sagittal_221.jpg -noquit
# -viewport axial -slice 127 221 127 -ss  ./img_save/T1_axial_221.jpg -noquit
# -viewport coronal -slice 127 127 221 -ss  ./img_save/T1_coronal_221.jpg -noquit
# -viewport sagittal -slice 222 127 127 -ss  ./img_save/T1_sagittal_222.jpg -noquit
# -viewport axial -slice 127 222 127 -ss  ./img_save/T1_axial_222.jpg -noquit
# -viewport coronal -slice 127 127 222 -ss  ./img_save/T1_coronal_222.jpg -noquit
# -viewport sagittal -slice 223 127 127 -ss  ./img_save/T1_sagittal_223.jpg -noquit
# -viewport axial -slice 127 223 127 -ss  ./img_save/T1_axial_223.jpg -noquit
# -viewport coronal -slice 127 127 223 -ss  ./img_save/T1_coronal_223.jpg -noquit
# -viewport sagittal -slice 224 127 127 -ss  ./img_save/T1_sagittal_224.jpg -noquit
# -viewport axial -slice 127 224 127 -ss  ./img_save/T1_axial_224.jpg -noquit
# -viewport coronal -slice 127 127 224 -ss  ./img_save/T1_coronal_224.jpg -noquit
# -viewport sagittal -slice 225 127 127 -ss  ./img_save/T1_sagittal_225.jpg -noquit
# -viewport axial -slice 127 225 127 -ss  ./img_save/T1_axial_225.jpg -noquit
# -viewport coronal -slice 127 127 225 -ss  ./img_save/T1_coronal_225.jpg -noquit
# -viewport sagittal -slice 226 127 127 -ss  ./img_save/T1_sagittal_226.jpg -noquit
# -viewport axial -slice 127 226 127 -ss  ./img_save/T1_axial_226.jpg -noquit
# -viewport coronal -slice 127 127 226 -ss  ./img_save/T1_coronal_226.jpg -noquit
# -viewport sagittal -slice 227 127 127 -ss  ./img_save/T1_sagittal_227.jpg -noquit
# -viewport axial -slice 127 227 127 -ss  ./img_save/T1_axial_227.jpg -noquit
# -viewport coronal -slice 127 127 227 -ss  ./img_save/T1_coronal_227.jpg -noquit
# -viewport sagittal -slice 228 127 127 -ss  ./img_save/T1_sagittal_228.jpg -noquit
# -viewport axial -slice 127 228 127 -ss  ./img_save/T1_axial_228.jpg -noquit
# -viewport coronal -slice 127 127 228 -ss  ./img_save/T1_coronal_228.jpg -noquit
# -viewport sagittal -slice 229 127 127 -ss  ./img_save/T1_sagittal_229.jpg -noquit
# -viewport axial -slice 127 229 127 -ss  ./img_save/T1_axial_229.jpg -noquit
# -viewport coronal -slice 127 127 229 -ss  ./img_save/T1_coronal_229.jpg -noquit
# -viewport sagittal -slice 230 127 127 -ss  ./img_save/T1_sagittal_230.jpg -noquit
# -viewport axial -slice 127 230 127 -ss  ./img_save/T1_axial_230.jpg -noquit
# -viewport coronal -slice 127 127 230 -ss  ./img_save/T1_coronal_230.jpg -noquit
# -viewport sagittal -slice 231 127 127 -ss  ./img_save/T1_sagittal_231.jpg -noquit
# -viewport axial -slice 127 231 127 -ss  ./img_save/T1_axial_231.jpg -noquit
# -viewport coronal -slice 127 127 231 -ss  ./img_save/T1_coronal_231.jpg -noquit
# -viewport sagittal -slice 232 127 127 -ss  ./img_save/T1_sagittal_232.jpg -noquit
# -viewport axial -slice 127 232 127 -ss  ./img_save/T1_axial_232.jpg -noquit
# -viewport coronal -slice 127 127 232 -ss  ./img_save/T1_coronal_232.jpg -noquit
# -viewport sagittal -slice 233 127 127 -ss  ./img_save/T1_sagittal_233.jpg -noquit
# -viewport axial -slice 127 233 127 -ss  ./img_save/T1_axial_233.jpg -noquit
# -viewport coronal -slice 127 127 233 -ss  ./img_save/T1_coronal_233.jpg -noquit
# -viewport sagittal -slice 234 127 127 -ss  ./img_save/T1_sagittal_234.jpg -noquit
# -viewport axial -slice 127 234 127 -ss  ./img_save/T1_axial_234.jpg -noquit
# -viewport coronal -slice 127 127 234 -ss  ./img_save/T1_coronal_234.jpg -noquit
# -viewport sagittal -slice 235 127 127 -ss  ./img_save/T1_sagittal_235.jpg -noquit
# -viewport axial -slice 127 235 127 -ss  ./img_save/T1_axial_235.jpg -noquit
# -viewport coronal -slice 127 127 235 -ss  ./img_save/T1_coronal_235.jpg -noquit
# -viewport sagittal -slice 236 127 127 -ss  ./img_save/T1_sagittal_236.jpg -noquit
# -viewport axial -slice 127 236 127 -ss  ./img_save/T1_axial_236.jpg -noquit
# -viewport coronal -slice 127 127 236 -ss  ./img_save/T1_coronal_236.jpg -noquit
# -viewport sagittal -slice 237 127 127 -ss  ./img_save/T1_sagittal_237.jpg -noquit
# -viewport axial -slice 127 237 127 -ss  ./img_save/T1_axial_237.jpg -noquit
# -viewport coronal -slice 127 127 237 -ss  ./img_save/T1_coronal_237.jpg -noquit
# -viewport sagittal -slice 238 127 127 -ss  ./img_save/T1_sagittal_238.jpg -noquit
# -viewport axial -slice 127 238 127 -ss  ./img_save/T1_axial_238.jpg -noquit
# -viewport coronal -slice 127 127 238 -ss  ./img_save/T1_coronal_238.jpg -noquit
# -viewport sagittal -slice 239 127 127 -ss  ./img_save/T1_sagittal_239.jpg -noquit
# -viewport axial -slice 127 239 127 -ss  ./img_save/T1_axial_239.jpg -noquit
# -viewport coronal -slice 127 127 239 -ss  ./img_save/T1_coronal_239.jpg -noquit
# -viewport sagittal -slice 240 127 127 -ss  ./img_save/T1_sagittal_240.jpg -noquit
# -viewport axial -slice 127 240 127 -ss  ./img_save/T1_axial_240.jpg -noquit
# -viewport coronal -slice 127 127 240 -ss  ./img_save/T1_coronal_240.jpg -noquit
# -viewport sagittal -slice 241 127 127 -ss  ./img_save/T1_sagittal_241.jpg -noquit
# -viewport axial -slice 127 241 127 -ss  ./img_save/T1_axial_241.jpg -noquit
# -viewport coronal -slice 127 127 241 -ss  ./img_save/T1_coronal_241.jpg -noquit
# -viewport sagittal -slice 242 127 127 -ss  ./img_save/T1_sagittal_242.jpg -noquit
# -viewport axial -slice 127 242 127 -ss  ./img_save/T1_axial_242.jpg -noquit
# -viewport coronal -slice 127 127 242 -ss  ./img_save/T1_coronal_242.jpg -noquit
# -viewport sagittal -slice 243 127 127 -ss  ./img_save/T1_sagittal_243.jpg -noquit
# -viewport axial -slice 127 243 127 -ss  ./img_save/T1_axial_243.jpg -noquit
# -viewport coronal -slice 127 127 243 -ss  ./img_save/T1_coronal_243.jpg -noquit
# -viewport sagittal -slice 244 127 127 -ss  ./img_save/T1_sagittal_244.jpg -noquit
# -viewport axial -slice 127 244 127 -ss  ./img_save/T1_axial_244.jpg -noquit
# -viewport coronal -slice 127 127 244 -ss  ./img_save/T1_coronal_244.jpg -noquit
# -viewport sagittal -slice 245 127 127 -ss  ./img_save/T1_sagittal_245.jpg -noquit
# -viewport axial -slice 127 245 127 -ss  ./img_save/T1_axial_245.jpg -noquit
# -viewport coronal -slice 127 127 245 -ss  ./img_save/T1_coronal_245.jpg -noquit
# -viewport sagittal -slice 246 127 127 -ss  ./img_save/T1_sagittal_246.jpg -noquit
# -viewport axial -slice 127 246 127 -ss  ./img_save/T1_axial_246.jpg -noquit
# -viewport coronal -slice 127 127 246 -ss  ./img_save/T1_coronal_246.jpg -noquit
# -viewport sagittal -slice 247 127 127 -ss  ./img_save/T1_sagittal_247.jpg -noquit
# -viewport axial -slice 127 247 127 -ss  ./img_save/T1_axial_247.jpg -noquit
# -viewport coronal -slice 127 127 247 -ss  ./img_save/T1_coronal_247.jpg -noquit
# -viewport sagittal -slice 248 127 127 -ss  ./img_save/T1_sagittal_248.jpg -noquit
# -viewport axial -slice 127 248 127 -ss  ./img_save/T1_axial_248.jpg -noquit
# -viewport coronal -slice 127 127 248 -ss  ./img_save/T1_coronal_248.jpg -noquit
# -viewport sagittal -slice 249 127 127 -ss  ./img_save/T1_sagittal_249.jpg -noquit
# -viewport axial -slice 127 249 127 -ss  ./img_save/T1_axial_249.jpg -noquit
# -viewport coronal -slice 127 127 249 -ss  ./img_save/T1_coronal_249.jpg -noquit
# -viewport sagittal -slice 250 127 127 -ss  ./img_save/T1_sagittal_250.jpg -noquit
# -viewport axial -slice 127 250 127 -ss  ./img_save/T1_axial_250.jpg -noquit
# -viewport coronal -slice 127 127 250 -ss  ./img_save/T1_coronal_250.jpg -noquit
# -viewport sagittal -slice 251 127 127 -ss  ./img_save/T1_sagittal_251.jpg -noquit
# -viewport axial -slice 127 251 127 -ss  ./img_save/T1_axial_251.jpg -noquit
# -viewport coronal -slice 127 127 251 -ss  ./img_save/T1_coronal_251.jpg -noquit
# -viewport sagittal -slice 252 127 127 -ss  ./img_save/T1_sagittal_252.jpg -noquit
# -viewport axial -slice 127 252 127 -ss  ./img_save/T1_axial_252.jpg -noquit
# -viewport coronal -slice 127 127 252 -ss  ./img_save/T1_coronal_252.jpg -noquit
# -viewport sagittal -slice 253 127 127 -ss  ./img_save/T1_sagittal_253.jpg -noquit
# -viewport axial -slice 127 253 127 -ss  ./img_save/T1_axial_253.jpg -noquit
# -viewport coronal -slice 127 127 253 -ss  ./img_save/T1_coronal_253.jpg -noquit
# -viewport sagittal -slice 254 127 127 -ss  ./img_save/T1_sagittal_254.jpg -noquit
# -viewport axial -slice 127 254 127 -ss  ./img_save/T1_axial_254.jpg -noquit
# -viewport coronal -slice 127 127 254 -ss  ./img_save/T1_coronal_254.jpg -noquit
# -viewport sagittal -slice 255 127 127 -ss  ./img_save/T1_sagittal_255.jpg -noquit
# -viewport axial -slice 127 255 127 -ss  ./img_save/T1_axial_255.jpg -noquit
# -viewport coronal -slice 127 127 255 -ss  ./img_save/T1_coronal_255.jpg -noquit
# -quit

# %%
##running in freesurfer (shutil?)

#saving the thing after running 
import imageio
import glob
sagittal = glob.glob('/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/*sagittal*jpg')
axial = glob.glob('/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/*axial*jpg')
coronal = glob.glob('/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/*coronal*jpg')

# %%
def get_slice(name):
    return name.replace('.','_').split('_')[-2]
sagittal.sort(key = get_slice)
axial.sort(key = get_slice)
coronal.sort(key = get_slice)

sagittal_gif = []
for filename in sagittal:
    sagittal_gif.append(imageio.imread(filename))

axial_gif = []
for filename in axial:
    axial_gif.append(imageio.imread(filename))


coronal_gif = []
for filename in coronal:
    coronal_gif.append(imageio.imread(filename))


imageio.mimsave('/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/sagittal.gif', sagittal_gif)
imageio.mimsave('/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/axial.gif', axial_gif)
imageio.mimsave('/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/coronal.gif', coronal_gif)
# Out:
# /var/folders/m3/y3bh88f92_5d37clpvn8jg_00000gn/T/ipykernel_3409/3483306850.py:9: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   sagittal_gif.append(imageio.imread(filename))
# /var/folders/m3/y3bh88f92_5d37clpvn8jg_00000gn/T/ipykernel_3409/3483306850.py:13: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   axial_gif.append(imageio.imread(filename))
# /var/folders/m3/y3bh88f92_5d37clpvn8jg_00000gn/T/ipykernel_3409/3483306850.py:18: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   coronal_gif.append(imageio.imread(filename))

# %%
sagittal
# Out:
# ['/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_000.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_020.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_040.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_060.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_080.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_100.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_120.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_140.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_160.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_180.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_200.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_220.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_240.jpg']

# %%
sagittal.sort(key=get_slice)

# %%
sagittal
# Out:
# ['/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_000.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_020.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_040.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_060.jpg']

# %%
sagittal[0].split('_')[-3]
# Out:
# '0'

# %%
sagittal
#이걸 어떻게 하느냐가 중요 (어떻게 sorting할지)
# Out:
# ['/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_0_127_127.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_100_127_127.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_125_127_127.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_150_127_127.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_175_127_127.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_200_127_127.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_225_127_127.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_250_127_127.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_25_127_127.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_50_127_127.jpg',
#  '/Users/eunmi/Desktop/QSIPREP/CHA_INFANT/sub-140989_well_done/infant_freesurfer/img_save/T1_sagittal_75_127_127.jpg']

# %%
a = ["002","001","010","100"
    ]

# %%
a.sort()

# %%
a
# Out:
# ['001', '002', '010', '100']
